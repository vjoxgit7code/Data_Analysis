# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.head(20)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5    263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6     99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8    325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11   846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# ...

# %%
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Location'].unique()
# Out:
# array(['Brookfield', 'Water tower', 'Park lane'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales[200:202]
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35   Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07   Male  Water tower  Chicago     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3

# %%
sales.tail()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Gender']=='Female'].head()
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 3    Sporting     89         4    356    Gpay       1
# 4       Books     82         5    410    Cash       4
# 9       Books     80         2    160    Cash       4
# 10  Furniture     35         4    140    Gpay       4

# %%
sales[sales['Total']<100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 13    942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 17     90524319  3/19/2018  18:18    Male    Park lane   Dallas    Yes
# 22    761515143  1/15/2018  16:08  Female    Park lane   Dallas     No
# 23     56578535  3/23/2018  10:11    Male  Water tower  Chicago    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 986   321374195  3/17/2018  14:16  Female  Water tower  Chicago     No
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales['Payment'].unique
# Out:
# <bound method Series.unique of 0      Cash
# 1      Card
# 2      Cash
# 3      Gpay
# 4      Cash
#        ...
# 995    Card
# 996    Gpay
# 997    Card
# 998    Cash
# 999    Gpay
# Name: Payment, Length: 1000, dtype: object>

# %%
sales[sales['Payment']=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['City']=='NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales['Category'].unique
# Out:
# <bound method Series.unique of 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 995    Groceries
# 996    Groceries
# 997     Clothing
# 998     Clothing
# 999     Clothing
# Name: Category, Length: 1000, dtype: object>

# %%
sales[101:200]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 101    42787009  3/28/2018  11:25  Female    Park lane   Dallas    Yes
# 102   780195692  2/20/2018  12:42  Female    Park lane   Dallas     No
# 103   881639873  2/27/2018  15:05    Male    Park lane   Dallas    Yes
# 104   443388850   2/5/2018  16:31    Male   Brookfield  NewYork    Yes
# 105   635503529  3/24/2018  15:17    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 195   343603860   2/4/2018  14:57  Female    Park lane   Dallas     No
# 196   925499362  1/12/2018  11:22  Female   Brookfield  NewYork    Yes
# 197   579316236   3/1/2018  13:44  Female  Water tower  Chicago    Yes
# 198   445531158   2/9/2018  20:19  Female    Park lane   Dallas     No
# 199   805526095  3/27/2018  18:00    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 101   Clothing     30         3     90    Card       5
# ...

# %%
#Arithmetic operations

# %%
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Rating']
# Out:
# 2972

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales[sales['Total']==sales.min()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
#groupby

# %%
sales.groupby('City')

# %%
sales.groupby('City').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Gender')['Payment'].sum()
# Out:
# Gender
# Female    CardGpayCashCashGpayGpayGpayCardGpayGpayCashCa...
# Male      CashCashGpayCashCashCardCardCashCashCashGpayCa...
# Name: Payment, dtype: object

# %%
sales.groupby('City')['Payment'].sum()
# Out:
# City
# Chicago    CardCashCashGpayCashGpayGpayCardGpayGpayCashGp...
# Dallas     GpayCashCashCardCashCardCashCashGpayCashCardCa...
# NewYork    CashGpayGpayGpayCardGpayGpayCashCardCardCardCa...
# Name: Payment, dtype: object

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
# which location has highest & lowest sales?

# %%
Location_list=sales.groupby('Location')

# %%
Location=[x for x,y in Location_list]

# %%
Location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
#Represent the sales on a bar chart,also show the market share for each location using a pie chart

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(Location,sales.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=Location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba75590640>,
# ...
#  [Text(0.5080357843151303, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.27711042780825285, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
# which location has more females and which location has more males?

# %%
location_sales=sales.groupby(['Gender','Location']).count()['Invoice ID']
location_sales
# Out:
# Gender  Location
# Female  Brookfield     179
#         Park lane      179
#         Water tower    143
# Male    Brookfield     161
#         Park lane      153
#         Water tower    185
# Name: Invoice ID, dtype: int64

# %%
unstacked_sales=location_sales.unstack(level=0)
unstacked_sales
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
unstacked_sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#what day of the month make most sales?

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sales['Date']) #pd=pandas
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
pd.to_datetime(sales['Date']).dt.day  #dt.year,dt.day,dt.month
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
day_sales=sales.groupby('Day').sum()['Total']

# %%
day_sales
# Out:
# Day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
day_sales.plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
# which branch has more members vs which has less members ?
# which branch has highest Rating vs which has lowest  ?

# %%
sales.head(5)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
Member=sales.groupby(['Member','Location']).count()['Invoice ID']
Member
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
Members=Member.unstack(level=0)
Members
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
Members.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
Rating=sales.groupby(['Location']).mean()['Rating']
Rating
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
Rating.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
# which location has more females and males ?

# %%
Female_shipping=sales.groupby(['City','Gender']).count()['Invoice ID']
Female_shipping
# Out:
# City     Gender
# Chicago  Female    143
#          Male      185
# Dallas   Female    179
#          Male      153
# NewYork  Female    179
#          Male      161
# Name: Invoice ID, dtype: int64

# %%
unstack=Female_shipping.unstack(level=0)

# %%
unstack.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
# who spends more men or female ?

# %%
Spends=sales.groupby('Gender').sum()
Spends
# Out:
#           Invoice ID  Price  Quantity   Total  Rating   Day
# Gender
# Female  253138028847  25474      2069  106452    1517  7700
# Male    241355024494  25638      1990  101336    1455  7556

# %%
Spends.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
# which type of customer spends more members or non members ?

# %%
mem=sales.groupby('Member').sum()['Total']
mem
mem.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Member'>

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
# which product line sells more ?

# %%
product_sales = sales.groupby('Category').sum()['Quantity']
product_sales
product_sales.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
# which product line is popular among men vs female ?

# %%
product_sales_gender = sales.groupby(['Category', 'Gender']).sum()['Quantity']
product_sales_gender
product_sales_gender.unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
# which month make more sells ?

# %%
sales['Month'] = pd.to_datetime(sales['Date']).dt.month

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
sales_by_month=sales.groupby('Month').sum()['Total']

# %%
sales_by_month.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.grid()
